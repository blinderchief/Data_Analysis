# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot') #plotsheet
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv('coaster_db.csv')

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.drop(['Opening date'],axis=1)
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
#Data Preparation

df = df[['coaster_name',
    # 'Length', 'Speed',
      'Location', 'Status', 
      #'Opening date',
     #  'Type', 
     'Manufacturer', 
     #'Height restriction', 'Model', 'Height',
      # 'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
      # 'Track layout', 'Fastrack available', 'Soft opening date.1',
      #  'Closing date', 
      #  'Opened', 'Replaced by', 'Website',
      #  'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
      #  'Single rider line available', 'Restraint Style',
      #  'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
      #  'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
       #'height_value', 'height_unit', 'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
#rename our columns
df = df.rename(columns={'coaster_name':'Coaster_Name','year_introduced':'Year_Introduced','Location':'Location','Status':'Status','Manufacturer':'Manufacturer','latitude':'Latitude','longitude':'Longitude','Type_Main':'Type','opening_date_clean':'Opening_Date','speed_mph':'Speed','Inversions_clean':'Inversions','Gforce_clean':'Gforce'})

# %%
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# Latitude           275
# Longitude          275
# Type                 0
# Opening_Date       250
# Speed              150
# Inversions           0
# Gforce             725
# dtype: int64

# %%
df.duplicated().sum()
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, Latitude, Longitude, Type, Opening_Date, Speed, Inversions, Gforce]
# Index: []

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])].head(5) # here you will which rows are duplicated
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      Latitude  Longitude   Type Opening_Date  Speed  Inversions  Gforce
# ...

# %%
df.query('Coaster_Name == "Crystal Beach Cyclone"') # here you will see the duplicated rows
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude  Type Opening_Date  Speed  \
# 39             1926   42.8617   -79.0598  Wood   1926-01-01   60.0
# 43             1927   42.8617   -79.0598  Wood   1926-01-01   60.0
#
#     Inversions  Gforce
# 39           0     4.0
# 43           0     4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type', 'Opening_Date', 'Speed', 'Inversions',
#        'Gforce'],
#       dtype='object')

# %%
df.duplicated(subset=['Coaster_Name','Location','Opening_Date']).sum()
# Out:
# np.int64(97)

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])]\
.reset_index(drop=True).copy()

# %%
df.head(5)
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#     Type Opening_Date  Speed  Inversions  Gforce
# ...

# %%
df.shape
# Out:
# (990, 12)

# %% [markdown]
# Feature Understanding

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1952     1
# 1956     1
# 1961     1
# 1955     1
# 1959     1
# Name: count, Length: 101, dtype: int64

# %%
ax = df['Year_Introduced'].value_counts().head(10) \
.plot(kind='bar',title='Number of Coasters Introduced by Year')
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Number of Coasters')
plt.show()

# %%
ax=df['Speed'].plot(kind='hist', title='Speed of Coasters (mph)', bins=20)
ax.set_xlabel('Speed')
# Out:
# Text(0.5, 0, 'Speed')

# %%
ax=df['Speed'].plot(kind='kde', title='Speed of Coasters (mph)')
ax.set_xlabel('Speed')
# Out:
# Text(0.5, 0, 'Speed')

# %% [markdown]
# Feature Relationship

# %%
df.plot(kind='scatter', x='Speed', y='Gforce', title='Speed vs Gforce')
plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type', 'Opening_Date', 'Speed', 'Inversions',
#        'Gforce'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x='Speed', y='Gforce', hue='Type')
plt.show()

# %%
sns.pairplot(df[['Speed','Gforce','Year_Introduced']], hue='Year_Introduced')
plt.show()

# %%
sns.pairplot(df,vars=['Year_Introduced','Speed','Gforce','Inversions'],hue='Type')
plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type', 'Opening_Date', 'Speed', 'Inversions',
#        'Gforce'],
#       dtype='object')

# %%
df_corr = df[['Speed','Gforce','Inversions','Year_Introduced']].dropna().corr()
df_corr
# Out:
#                     Speed    Gforce  Inversions  Year_Introduced
# Speed            1.000000  0.503828    0.117382         0.252317
# Gforce           0.503828  1.000000    0.391100         0.105636
# Inversions       0.117382  0.391100    1.000000         0.135972
# Year_Introduced  0.252317  0.105636    0.135972         1.000000

# %%
sns.heatmap(df_corr, annot=True)
plt.show()

# %%
df.query('Location !="Other"')\
.groupby('Location')['Speed']\
.agg(['mean','count'])\
.query('count >= 10')\
.sort_values('mean',ascending=False)\
.plot(kind='barh',y='mean',title='Mean Speed by Location')
plt.show()

# %%
df.query('Location !="Other"')\
.groupby('Location')['Speed']\
.agg(['mean','median','std','count'])\
.query('count >= 10')\
.sort_values('mean',ascending=False)\
.plot(kind='bar',y='mean',yerr='std',title='Mean Speed by Location')
plt.show()
